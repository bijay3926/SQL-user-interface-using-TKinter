# %%
import tkinter as tk
import mysql.connector 
from tkinter import *
from tkinter import messagebox
  
def cred():
     
    user = Username.get()
    passw = password.get()
    data= database.get()

    login(user, passw, data)
  
 
def login(user, passw, data):
     
    if passw:
        db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                     password = passw,
                                     db =data)
        cursor = db.cursor()
         

    else:
        db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                     data =data)
        cursor = db.cursor()
def save_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db =data)
    cursor = db.cursor()
    cursor.execute("SHOW DATABASES")
    i=1
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='databases',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
        i=i+1
    db.close()

def input_query():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute(userquery.get())
    i=0 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])    
        i=i+1  
def inner_join():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("SELECT * from cancerdata1 inner join cancerdata2 on cancerdata1.id=cancerdata2.id")
    i=0 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='id',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='diagnosis',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='radius_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='texture_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=3)
            e=Label(root,width=10,text='perimeter_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=4)
            e=Label(root,width=10,text='area_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=5)
            e=Label(root,width=10,text='smoothness_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=6)
            e=Label(root,width=10,text='compactness_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=7)
            e=Label(root,width=10,text='concavity_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=8)
            e=Label(root,width=10,text='concave points_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=9)
            e=Label(root,width=10,text='id',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=10)
            e=Label(root,width=10,text='symmetry_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=11)
            e=Label(root,width=10,text='fractal_dimension_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=12)
            e=Label(root,width=10,text='radius_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=13)
            e=Label(root,width=10,text='texture_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=14)
            e=Label(root,width=10,text='perimeter_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=15)
            e=Label(root,width=10,text='area_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=16)
            e=Label(root,width=10,text='smoothness_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=17)
            e=Label(root,width=10,text='compactness_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=18)
        i=i+1 


def malignant():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("select * from cancerdata1 inner join cancerdata2 on cancerdata1.id = cancerdata2.id where diagnosis = 'M'")
    i=0 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='id',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='diagnosis',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='radius_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='texture_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=3)
            e=Label(root,width=10,text='perimeter_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=4)
            e=Label(root,width=10,text='area_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=5)
            e=Label(root,width=10,text='smoothness_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=6)
            e=Label(root,width=10,text='compactness_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=7)
            e=Label(root,width=10,text='concavity_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=8)
            e=Label(root,width=10,text='concave points_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=9)
            e=Label(root,width=10,text='symmetry_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=10)
            e=Label(root,width=10,text='fractal_dimension_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=11)
            e=Label(root,width=10,text='radius_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=12)
            e=Label(root,width=10,text='texture_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=13)
            e=Label(root,width=10,text='perimeter_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=14)
            e=Label(root,width=10,text='area_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=15)
            e=Label(root,width=10,text='smoothness_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=16)
            e=Label(root,width=10,text='compactness_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=17)
        i=i+1 
        
def benign():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("select * from cancerdata1 inner join cancerdata2 on cancerdata1.id = cancerdata2.id where diagnosis = 'B'")
    i=0 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='id',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='diagnosis',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='radius_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='texture_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=3)
            e=Label(root,width=10,text='perimeter_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=4)
            e=Label(root,width=10,text='area_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=5)
            e=Label(root,width=10,text='smoothness_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=6)
            e=Label(root,width=10,text='compactness_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=7)
            e=Label(root,width=10,text='concavity_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=8)
            e=Label(root,width=10,text='concave points_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=9)
            e=Label(root,width=10,text='symmetry_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=10)
            e=Label(root,width=10,text='fractal_dimension_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=11)
            e=Label(root,width=10,text='radius_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=12)
            e=Label(root,width=10,text='texture_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=13)
            e=Label(root,width=10,text='perimeter_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=14)
            e=Label(root,width=10,text='area_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=15)
            e=Label(root,width=10,text='smoothness_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=16)
            e=Label(root,width=10,text='compactness_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=17)
        i=i+1 
        
def highradmean():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("select cancerdata1.id, cancerdata1.radius_mean, cancerdata1.diagnosis, cancerdata2.fractal_dimension_mean from cancerdata1 inner join cancerdata2 on cancerdata1.id = cancerdata2.id where radius_mean > 15")
    i=0 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='id',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='radius_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='diagnosis',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=2)
            e=Label(root,width=10,text='fractal_dimension_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=3)                        
        i=i+1 
def hardtexture():
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    cursor = db.cursor()
    cursor.execute("select cancerdata1.id, cancerdata1.diagnosis, cancerdata2.symmetry_mean from cancerdata1 inner join cancerdata2 on cancerdata1.id = cancerdata2.id where texture_mean > 20")
    i=0 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='id',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='diagnosis',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='symmetry_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=2)                       
        i=i+1    
        
def widelyspread():
    
    user = Username.get()
    passw = password.get()
    data= database.get()
    db = mysql.connector.connect(host ="localhost",
                                     user = user,
                                 password = passw,
                                     db = data)
    
    cursor = db.cursor()
    cursor.execute("select cancerdata2.texture_se, cancerdata1.diagnosis,cancerdata1.area_mean from cancerdata1 inner join cancerdata2 on cancerdata1.id = cancerdata2.id where area_mean > 1000")
    i=0 
    for student in cursor: 
        for j in range(len(student)):
            e = Entry(root, width=10, fg='black') 
            e.grid(row=i, column=j) 
            e.insert(END, student[j])
            e=Label(root,width=10,text='texture_se',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=0)
            e=Label(root,width=10,text='diagnosis',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=1)
            e=Label(root,width=10,text='area_mean',borderwidth=1, relief='ridge',anchor='w',bg='yellow')
            e.grid(row=0,column=2)                       
        i=i+1    

        
root = tk.Tk()
root.geometry("1200x1200")
root.configure(bg='gray')
root.title("Dashboard") 

welcome = tk.Label(root, text ="Welcome to SQL GUI platform", fg = "light blue", bg = "dark blue",font = "Verdana 24 bold italic")
welcome.place(x = 350, y = 20)

firstrow = tk.Label(root, text ="Username -", )
firstrow.place(x = 50, y = 150)

Username = tk.Entry(root, width = 35)
Username.place(x = 150, y = 150, width = 100)
     
secondrow = tk.Label(root, text ="Password -")
secondrow.place(x = 50, y = 180)
 
password = tk.Entry(root, width = 35)
password.place(x = 150, y = 180, width = 100)

thirdrow = tk.Label(root, text ="Database Name -")
thirdrow.place(x = 50, y = 210)
 
database = tk.Entry(root, width = 35)
database.place(x = 150, y = 210, width = 100)
 
submitbutton = tk.Button(root, text ="Login", font = "Verdana 12 bold italic",
                      bg ='pink', command = cred)
submitbutton.place(x = 150, y = 250, width = 155)

welcome1 = tk.Label(root, text ="Predefined queries", fg = "light blue", bg = "dark blue",font = "Verdana 12 bold italic")
welcome1.place(x = 600, y = 100)

welcome2 = tk.Label(root, text ="Enter Your Details", fg = "light blue", bg = "dark blue",font = "Verdana 12 bold italic")
welcome2.place(x = 100, y = 100)

save = tk.Button(root, text ="Show databases", font = "Verdana 12 bold italic",
                      bg ='pink', command = save_query)
save.place(x = 560, y = 150, width = 300)

inner= tk.Button(root, text ="Inner Join of Cancer Data", font = "Verdana 12 bold italic",
                      bg ='pink', command = inner_join)
inner.place(x = 560, y = 200, width = 300)
inner= tk.Button(root, text ="Malignant Cancer type patients", font = "Verdana 12 bold italic",
                      bg ='pink', command = malignant)
inner.place(x = 560, y = 250, width = 300)

inner= tk.Button(root, text ="Benign Cancer type patients", font = "Verdana 12 bold italic",
                      bg ='pink', command = benign)
inner.place(x = 560, y = 300, width = 300)

inner= tk.Button(root, text ="Tumors with high radii", font = "Verdana 12 bold italic",
                      bg ='pink', command = highradmean)
inner.place(x = 560, y = 350, width = 300)

inner= tk.Button(root, text ="Hard Texture Type Cases ", font = "Verdana 12 bold italic",
                      bg ='pink', command = hardtexture)
inner.place(x = 560, y = 400, width = 300)

inner= tk.Button(root, text ="Larger Sized Tumor Cases", font = "Verdana 12 bold italic",
                      bg ='pink', command = widelyspread)
inner.place(x = 560, y = 450, width = 300)

cond= tk.Button(root, text ="Run the Query", font = "Verdana 12 bold italic",
                      bg ='pink', command = input_query)
cond.place(x = 850, y = 595, width = 200)

query = tk.Label(root, text ="Enter your query:", font = "Verdana 12 bold italic"  )
query.place(x = 80, y = 600)
 
userquery = tk.Entry(root, width = 35)
userquery.place(x = 300, y = 600, width = 500)

root.mainloop()
